# %%
import PIL
import PIL.ImageDraw
import random

# %%
class RubkisCube:
    def __init__(self, moves_nr=3):
        self.cube = {"U":[['W', 'W', 'W'], ['W', 'W', 'W'], ['W', 'W', 'W']],
            "L":[['O', 'O', 'O'], ['O', 'O', 'O'], ['O', 'O', 'O']],
            "F":[['G', 'G', 'G'], ['G', 'G', 'G'], ['G', 'G', 'G']],
            "R":[['R', 'R', 'R'], ['R', 'R', 'R'], ['R', 'R', 'R']],
            "B":[['B', 'B', 'B'], ['B', 'B', 'B'], ['B', 'B', 'B']],
            "D":[['Y', 'Y', 'Y'], ['Y', 'Y', 'Y'], ['Y', 'Y', 'Y']]
        }
        self.shuffle(moves_nr)
        
    def __str__(self):
        string = ""
        for face in self.cube.values():
            for row in face:
                for square in row:
                    string+=square
        return string
    '''
    def get_color(self, color: str):
        match color:
            case "R":
                return (255,0,0)
            case "G":
                return (0,255,0)
            case "B":
                return (0,0,255)
            case "W":
                return (255,255,255)
            case "Y":
                return (255,255,0)
            case "O":
                return (255,128,0)
    '''
    def get_color(self, color: str):
        if color == "R":
            return (255,0,0)
        elif color == "G":
            return (0,255,0)
        elif color == "B":
            return (0,0,255)
        elif color == "W":
            return (255,255,255)
        elif color == "Y":
            return (255,255,0)
        elif color == "O":
            return (255,128,0)
             
    def draw_cube(self):
        square_size = 50
        im = PIL.Image.new(mode="RGB", size=(square_size*12,square_size*9))
        draw = PIL.ImageDraw.Draw(im)

        positions = {
            "U": (3, 0),
            "L": (0, 3),
            "F": (3, 3),
            "R": (6, 3),
            "B": (9, 3),
            "D": (3, 6) 
        }

        for side, pos in positions.items():
            base_x, base_y = pos[0] * square_size, pos[1] * square_size
            
            for row in range(3):
                for col in range(3):
                    color = self.get_color(self.cube[side][row][col])

                    x1 = base_x + (col * square_size)
                    y1 = base_y + (row * square_size)
                    x2 = x1 + square_size
                    y2 = y1 + square_size
                    
                    draw.rectangle(
                        xy=(x1, y1, x2, y2),
                        fill=color,
                        outline=(0, 0, 0)
                    )
        #im.show()
        return im
    
    def rotate(self, move: str):
        face = move[0]
        direction = "CCW" if "'" in move else "CW"
        
        old_face = [row[:] for row in self.cube[face]]
        for i in range(3):
            for j in range(3):
                if direction == "CW":
                    self.cube[face][j][2-i] = old_face[i][j]
                elif direction == "CCW":
                    self.cube[face][2-j][i] = old_face[i][j]

        if face == "U":
            if direction == "CW":
                temp = self.cube["L"][0][:]
                self.cube["L"][0] = self.cube["F"][0][:]
                self.cube["F"][0] = self.cube["R"][0][:]
                self.cube["R"][0] = self.cube["B"][0][:]
                self.cube["B"][0] = temp
            elif direction == "CCW":
                temp = self.cube["L"][0][:]
                self.cube["L"][0] = self.cube["B"][0][:]
                self.cube["B"][0] = self.cube["R"][0][:]
                self.cube["R"][0] = self.cube["F"][0][:]
                self.cube["F"][0] = temp

        elif face == "D":
            if direction == "CW":
                temp = self.cube["L"][2][:]
                self.cube["L"][2] = self.cube["B"][2][:]
                self.cube["B"][2] = self.cube["R"][2][:]
                self.cube["R"][2] = self.cube["F"][2][:]
                self.cube["F"][2] = temp
            elif direction == "CCW":
                temp = self.cube["L"][2][:]
                self.cube["L"][2] = self.cube["F"][2][:]
                self.cube["F"][2] = self.cube["R"][2][:]
                self.cube["R"][2] = self.cube["B"][2][:]
                self.cube["B"][2] = temp

        elif face == "F":
            if direction == "CW":
                temp = self.cube["U"][2][:]
                self.cube["U"][2] = [self.cube["L"][2][2], self.cube["L"][1][2], self.cube["L"][0][2]]
                self.cube["L"][0][2], self.cube["L"][1][2], self.cube["L"][2][2] = self.cube["D"][0][:]
                self.cube["D"][0] = [self.cube["R"][2][0], self.cube["R"][1][0], self.cube["R"][0][0]]
                self.cube["R"][0][0], self.cube["R"][1][0], self.cube["R"][2][0] = temp
            elif direction == "CCW":
                temp = self.cube["U"][2][:]
                self.cube["U"][2] = [self.cube["R"][0][0], self.cube["R"][1][0], self.cube["R"][2][0]]
                self.cube["R"][0][0], self.cube["R"][1][0], self.cube["R"][2][0] = self.cube["D"][0][::-1]
                self.cube["D"][0] = [self.cube["L"][0][2], self.cube["L"][1][2], self.cube["L"][2][2]]
                self.cube["L"][0][2], self.cube["L"][1][2], self.cube["L"][2][2] = temp[::-1]

        elif face == "B":
            if direction == "CW":
                temp = self.cube["U"][0][:]
                self.cube["U"][0] = [self.cube["R"][0][2], self.cube["R"][1][2], self.cube["R"][2][2]]
                self.cube["R"][0][2], self.cube["R"][1][2], self.cube["R"][2][2] = self.cube["D"][2][::-1]
                self.cube["D"][2] = [self.cube["L"][0][0], self.cube["L"][1][0], self.cube["L"][2][0]]
                self.cube["L"][0][0], self.cube["L"][1][0], self.cube["L"][2][0] = temp[::-1]
            elif direction == "CCW":
                temp = self.cube["U"][0][:]
                self.cube["U"][0] = [self.cube["L"][2][0], self.cube["L"][1][0], self.cube["L"][0][0]]
                self.cube["L"][0][0], self.cube["L"][1][0], self.cube["L"][2][0] = self.cube["D"][2][:]
                self.cube["D"][2] = [self.cube["R"][2][2], self.cube["R"][1][2], self.cube["R"][0][2]]
                self.cube["R"][0][2], self.cube["R"][1][2], self.cube["R"][2][2] = temp

        elif face == "L":
            if direction == "CW":
                temp = [self.cube["U"][i][0] for i in range(3)]
                for i in range(3): self.cube["U"][i][0] = self.cube["B"][2-i][2]
                for i in range(3): self.cube["B"][i][2] = self.cube["D"][2-i][0]
                for i in range(3): self.cube["D"][i][0] = self.cube["F"][i][0]
                for i in range(3): self.cube["F"][i][0] = temp[i]
            elif direction == "CCW":
                temp = [self.cube["U"][i][0] for i in range(3)]
                for i in range(3): self.cube["U"][i][0] = self.cube["F"][i][0]
                for i in range(3): self.cube["F"][i][0] = self.cube["D"][i][0]
                for i in range(3): self.cube["D"][i][0] = self.cube["B"][2-i][2]
                for i in range(3): self.cube["B"][i][2] = temp[2-i]

        elif face == "R":
            if direction == "CW":
                temp = [self.cube["U"][i][2] for i in range(3)]
                for i in range(3): self.cube["U"][i][2] = self.cube["F"][i][2]
                for i in range(3): self.cube["F"][i][2] = self.cube["D"][i][2]
                for i in range(3): self.cube["D"][i][2] = self.cube["B"][2-i][0]
                for i in range(3): self.cube["B"][i][0] = temp[2-i]
            elif direction == "CCW":
                temp = [self.cube["U"][i][2] for i in range(3)]
                for i in range(3): self.cube["U"][i][2] = self.cube["B"][2-i][0]
                for i in range(3): self.cube["B"][i][0] = self.cube["D"][2-i][2]
                for i in range(3): self.cube["D"][i][2] = self.cube["F"][i][2]
                for i in range(3): self.cube["F"][i][2] = temp[i]

    def shuffle(self, moves=50):
        for _ in range(moves):
            move = random.choice(["F","R","U","B","L","D","F'","R'","U'","B'","L'","D'"])
            self.rotate(move)
        return self
    
    def check_score(self):
        return sum(sum(row.count(face[1][1]) for row in face) for face in self.cube.values())
    
    def check_done(self):
        return self.check_score() == 54
    
    def step(self, action):
        move = ["F","R","U","B","L","D","F'","R'","U'","B'","L'","D'"][action]
        self.rotate(move)
        #reward = 200 if self.check_score()==54 else (self.check_score()-54)/10
        #return reward
        return self.check_score()

# %% [markdown]
# # Custom Environment

# %% [markdown]
# # Building the Environment

# %%
import gym
from gym import Env
from gym.spaces import Discrete, Box, Dict, MultiBinary, MultiDiscrete, Tuple
import numpy as np
import random
import os
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %%
class CubeEnv(Env):
    def __init__(self):
        self.action_space = Discrete(12)
        
        self.color_to_idx = {
            'W': 0,  # White
            'O': 1,  # Orange
            'G': 2,  # Green
            'R': 3,  # Red
            'B': 4,  # Blue
            'Y': 5   # Yellow
        }
        self.observation_space = Box(low=0, high=5, shape=(54,), dtype=np.int8)
        
        self.state = RubkisCube()
        self.moves_left = 50
        self.previous_score = self.state.check_score()
        
    def _state_to_observation(self):
        state_str = str(self.state)  # You might need to adjust this based on your RubkisCube class
        return np.array([self.color_to_idx[c] for c in state_str], dtype=np.int8)
    
    def step(self, action):
        current_score = self.state.step(action)
        self.moves_left -= 1

        improvement = current_score - self.previous_score
        move_penalty = -0.1  

        done = True if current_score==54 else False
        
        if done:
            reward = 200
        else:
            reward = improvement * 2.0  # Multiply improvement by 2 for stronger signal
            reward += move_penalty  # Add move penalty
            
        if self.moves_left == 0:
            done = True
            reward += (current_score / 54.0) * 20.0

        self.previous_score = current_score

        info = {
            'moves_remaining': self.moves_left,
            'current_score': current_score,
            'completion_percentage': (current_score / 54.0) * 100
            }
            
        return self._state_to_observation(), reward, done, info
    
    def render(self):
        pass
        #return self.state.draw_cube()
    
    def reset(self):
        self.state = RubkisCube()
        self.moves_left = 50
        self.previous_score = self.state.check_score()

        return self._state_to_observation()

# %% [markdown]
# # Test Environment

# %%
env_cub = CubeEnv()

# %%
episodes = 1
for episode in range(episodes):
    obs = env_cub.reset()
    done = False
    score = 0
    
    for _ in range(50):
        action = env_cub.action_space.sample()
        obs, reward, done, info = env_cub.step(action)
        score += reward
        print(score)
        #env_cub.render().show()
        if done:
            break
# Out:
# -16.1
# -26.200000000000003
# -28.300000000000004
# -30.400000000000006
# -36.50000000000001
# -40.60000000000001
# -34.70000000000001
# -34.80000000000001
# -38.90000000000001
# -35.000000000000014
# -37.100000000000016
# -35.20000000000002
# -39.30000000000002
# -41.40000000000002
# -39.50000000000002
# -37.60000000000002
# -41.700000000000024
# -39.800000000000026
# -39.90000000000003
# -36.00000000000003
# -40.10000000000003
# -40.20000000000003
# -44.30000000000003
# -40.400000000000034
# -40.500000000000036
# -34.60000000000004
# -34.70000000000004
# -36.80000000000004
# -36.90000000000004
# -35.00000000000004
# -33.100000000000044
# -35.200000000000045
# -41.30000000000005
# -37.40000000000005
# -35.50000000000005
# -27.60000000000005
# -37.70000000000005
# -41.800000000000054
# -45.900000000000055
# -50.00000000000006
# -48.10000000000006
# -50.20000000000006
# -40.30000000000006
# -38.40000000000006
# -38.500000000000064
# -42.600000000000065
# -30.700000000000067
# -36.80000000000007
# -30.90000000000007
# -31.074074074074144

# %% [markdown]
# # Train Model

# %%
log_path = os.path.join('Training', 'Logs')
model = PPO('MlpPolicy', env_cub, verbose=1, tensorboard_log=log_path, device='cpu')
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# c:\Users\RoscaMitrut\.conda\envs\second_env\lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(

# %%
model.learn(total_timesteps=1_000_000)
# Out:
# Logging to Training\Logs\PPO_6
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.7     |
# |    ep_rew_mean     | -21.3    |
# | time/              |          |
# |    fps             | 1880     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 48.8        |
# |    ep_rew_mean          | -27.5       |
# | time/                   |             |
# |    fps                  | 1281        |
# |    iterations           | 2           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.007357899 |
# |    clip_fraction        | 0.0512      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.48       |
# |    explained_variance   | 7.52e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.5        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0184     |
# |    value_loss           | 122         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 49.5         |
# |    ep_rew_mean          | -28.7        |
# | time/                   |              |
# |    fps                  | 1177         |
# |    iterations           | 3            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0075655566 |
# |    clip_fraction        | 0.0255       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.48        |
# |    explained_variance   | 0.217        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 57.6         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0181      |
# |    value_loss           | 66.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49.5        |
# |    ep_rew_mean          | -26.4       |
# | time/                   |             |
# |    fps                  | 1127        |
# |    iterations           | 4           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.005654375 |
# |    clip_fraction        | 0.0222      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.47       |
# |    explained_variance   | 0.311       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.1        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.02       |
# |    value_loss           | 60.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49.5        |
# |    ep_rew_mean          | -27.2       |
# | time/                   |             |
# |    fps                  | 1102        |
# |    iterations           | 5           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.007548675 |
# |    clip_fraction        | 0.0627      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.47       |
# |    explained_variance   | 0.164       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.9        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0243     |
# |    value_loss           | 116         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 49           |
# |    ep_rew_mean          | -24          |
# | time/                   |              |
# |    fps                  | 1088         |
# |    iterations           | 6            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0074956114 |
# |    clip_fraction        | 0.0556       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.46        |
# |    explained_variance   | 0.42         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19.5         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0282      |
# |    value_loss           | 47.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 48.5        |
# |    ep_rew_mean          | -22.5       |
# | time/                   |             |
# |    fps                  | 1075        |
# |    iterations           | 7           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.008132629 |
# |    clip_fraction        | 0.0505      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.46       |
# |    explained_variance   | 0.28        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.7        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0289     |
# |    value_loss           | 80.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 47.5        |
# |    ep_rew_mean          | -21         |
# | time/                   |             |
# |    fps                  | 1070        |
# |    iterations           | 8           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.007904435 |
# |    clip_fraction        | 0.0575      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.45       |
# |    explained_variance   | 0.284       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.6        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0275     |
# |    value_loss           | 98.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 48.5         |
# |    ep_rew_mean          | -24.9        |
# | time/                   |              |
# |    fps                  | 1066         |
# |    iterations           | 9            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0073771197 |
# |    clip_fraction        | 0.0541       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.44        |
# |    explained_variance   | 0.255        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 32.5         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.0267      |
# |    value_loss           | 102          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49.5        |
# |    ep_rew_mean          | -29.1       |
# | time/                   |             |
# |    fps                  | 1060        |
# |    iterations           | 10          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.009002617 |
# |    clip_fraction        | 0.0751      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.43       |
# |    explained_variance   | 0.353       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.5        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0322     |
# |    value_loss           | 74          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49          |
# |    ep_rew_mean          | -24.4       |
# | time/                   |             |
# |    fps                  | 1051        |
# |    iterations           | 11          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.009064196 |
# |    clip_fraction        | 0.0811      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.42       |
# |    explained_variance   | 0.518       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17          |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0332     |
# |    value_loss           | 46.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 48.5        |
# |    ep_rew_mean          | -22.8       |
# | time/                   |             |
# |    fps                  | 1048        |
# |    iterations           | 12          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.008820401 |
# |    clip_fraction        | 0.0653      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.41       |
# |    explained_variance   | 0.118       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.6        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0301     |
# |    value_loss           | 142         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 48.5       |
# |    ep_rew_mean          | -23.6      |
# | time/                   |            |
# |    fps                  | 1047       |
# |    iterations           | 13         |
# |    time_elapsed         | 25         |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.01050082 |
# |    clip_fraction        | 0.1        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.4       |
# |    explained_variance   | 0.365      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 13.4       |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.04      |
# |    value_loss           | 70.5       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 49.5         |
# |    ep_rew_mean          | -27.4        |
# | time/                   |              |
# |    fps                  | 1046         |
# |    iterations           | 14           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0109440405 |
# |    clip_fraction        | 0.105        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.39        |
# |    explained_variance   | 0.38         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.2         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.0362      |
# |    value_loss           | 68.5         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 49         |
# |    ep_rew_mean          | -24.4      |
# | time/                   |            |
# |    fps                  | 1045       |
# |    iterations           | 15         |
# |    time_elapsed         | 29         |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.01079604 |
# |    clip_fraction        | 0.11       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.38      |
# |    explained_variance   | 0.514      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 17.9       |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.0398    |
# |    value_loss           | 40.3       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 48          |
# |    ep_rew_mean          | -21         |
# | time/                   |             |
# |    fps                  | 1044        |
# |    iterations           | 16          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.009511109 |
# |    clip_fraction        | 0.078       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.37       |
# |    explained_variance   | 0.278       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.7        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0332     |
# |    value_loss           | 91.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 47.1        |
# |    ep_rew_mean          | -16.6       |
# | time/                   |             |
# |    fps                  | 1040        |
# |    iterations           | 17          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.011191627 |
# |    clip_fraction        | 0.0999      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.36       |
# |    explained_variance   | 0.36        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.4        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0366     |
# |    value_loss           | 95.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 46.6        |
# |    ep_rew_mean          | -13.3       |
# | time/                   |             |
# |    fps                  | 1040        |
# |    iterations           | 18          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.012549928 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.34       |
# |    explained_variance   | 0.289       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.9        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0414     |
# |    value_loss           | 94.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 46.2        |
# |    ep_rew_mean          | -9.91       |
# | time/                   |             |
# |    fps                  | 1040        |
# |    iterations           | 19          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.008892212 |
# |    clip_fraction        | 0.0674      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.33       |
# |    explained_variance   | 0.013       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 261         |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0258     |
# |    value_loss           | 331         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 47.2        |
# |    ep_rew_mean          | -13.7       |
# | time/                   |             |
# |    fps                  | 1037        |
# |    iterations           | 20          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.009724041 |
# |    clip_fraction        | 0.0936      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.32       |
# |    explained_variance   | 0.0304      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 549         |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0291     |
# |    value_loss           | 259         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 48.6        |
# |    ep_rew_mean          | -18         |
# | time/                   |             |
# |    fps                  | 1034        |
# |    iterations           | 21          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.011589967 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.32       |
# |    explained_variance   | 0.527       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.3        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0399     |
# |    value_loss           | 42.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 48.6        |
# |    ep_rew_mean          | -19.7       |
# | time/                   |             |
# |    fps                  | 1033        |
# |    iterations           | 22          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.012479334 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.3        |
# |    explained_variance   | 0.101       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.7        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0366     |
# |    value_loss           | 182         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 48.1         |
# |    ep_rew_mean          | -16.6        |
# | time/                   |              |
# |    fps                  | 1031         |
# |    iterations           | 23           |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0110814925 |
# |    clip_fraction        | 0.106        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.29        |
# |    explained_variance   | 0.131        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.16         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.0364      |
# |    value_loss           | 150          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 48.1        |
# |    ep_rew_mean          | -17.6       |
# | time/                   |             |
# |    fps                  | 1028        |
# |    iterations           | 24          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.012753539 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.27       |
# |    explained_variance   | 0.289       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.3        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0418     |
# |    value_loss           | 96.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 48.6        |
# |    ep_rew_mean          | -20.8       |
# | time/                   |             |
# |    fps                  | 1027        |
# |    iterations           | 25          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.011628465 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.25       |
# |    explained_variance   | 0.243       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 381         |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0368     |
# |    value_loss           | 124         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 46.2        |
# |    ep_rew_mean          | -9.13       |
# | time/                   |             |
# |    fps                  | 1028        |
# |    iterations           | 26          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.012259968 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.23       |
# |    explained_variance   | 0.0995      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.4        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0361     |
# |    value_loss           | 229         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 46.2        |
# |    ep_rew_mean          | -7.75       |
# | time/                   |             |
# |    fps                  | 1025        |
# |    iterations           | 27          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.012028111 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.23       |
# |    explained_variance   | 0.0556      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.3        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0323     |
# |    value_loss           | 302         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 45.8        |
# |    ep_rew_mean          | -4.03       |
# | time/                   |             |
# |    fps                  | 1026        |
# |    iterations           | 28          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.013661372 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.2        |
# |    explained_variance   | 0.186       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 413         |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.038      |
# |    value_loss           | 144         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 42.4        |
# |    ep_rew_mean          | 10.5        |
# | time/                   |             |
# |    fps                  | 1026        |
# |    iterations           | 29          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.009189174 |
# |    clip_fraction        | 0.0981      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.18       |
# |    explained_variance   | -0.0434     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 394         |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0228     |
# |    value_loss           | 518         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 43.8        |
# |    ep_rew_mean          | 2.63        |
# | time/                   |             |
# |    fps                  | 1026        |
# |    iterations           | 30          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.011099616 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.15       |
# |    explained_variance   | 0.0212      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.2        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0304     |
# |    value_loss           | 358         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 44.7        |
# |    ep_rew_mean          | 0.79        |
# | time/                   |             |
# |    fps                  | 1025        |
# |    iterations           | 31          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.013030541 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.14       |
# |    explained_variance   | 0.142       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.3        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0335     |
# |    value_loss           | 234         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 42.3         |
# |    ep_rew_mean          | 13.3         |
# | time/                   |              |
# |    fps                  | 1021         |
# |    iterations           | 32           |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0130785145 |
# |    clip_fraction        | 0.143        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.13        |
# |    explained_variance   | 0.00241      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 22.9         |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.0308      |
# |    value_loss           | 369          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 44.8        |
# |    ep_rew_mean          | 1.09        |
# | time/                   |             |
# |    fps                  | 1022        |
# |    iterations           | 33          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.013184067 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.12       |
# |    explained_variance   | 0.0681      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20          |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.031      |
# |    value_loss           | 305         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 43.8         |
# |    ep_rew_mean          | 6.34         |
# | time/                   |              |
# |    fps                  | 1022         |
# |    iterations           | 34           |
# |    time_elapsed         | 68           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0147435535 |
# |    clip_fraction        | 0.158        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.11        |
# |    explained_variance   | 0.0573       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 22.4         |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.0358      |
# |    value_loss           | 247          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 42          |
# |    ep_rew_mean          | 15.3        |
# | time/                   |             |
# |    fps                  | 1020        |
# |    iterations           | 35          |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.012384181 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.08       |
# |    explained_variance   | 0.0547      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 140         |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0263     |
# |    value_loss           | 381         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 42.4        |
# |    ep_rew_mean          | 13.1        |
# | time/                   |             |
# |    fps                  | 1010        |
# |    iterations           | 36          |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.009832712 |
# |    clip_fraction        | 0.0849      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.05       |
# |    explained_variance   | -0.0567     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 152         |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0214     |
# |    value_loss           | 572         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 41.8        |
# |    ep_rew_mean          | 16.5        |
# | time/                   |             |
# |    fps                  | 1008        |
# |    iterations           | 37          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.013638908 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.04       |
# |    explained_variance   | 0.0446      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.1        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0251     |
# |    value_loss           | 388         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 40.7         |
# |    ep_rew_mean          | 24.9         |
# | time/                   |              |
# |    fps                  | 1006         |
# |    iterations           | 38           |
# |    time_elapsed         | 77           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0126079675 |
# |    clip_fraction        | 0.135        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.03        |
# |    explained_variance   | 0.0276       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 26.3         |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.0262      |
# |    value_loss           | 454          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 41.7        |
# |    ep_rew_mean          | 19          |
# | time/                   |             |
# |    fps                  | 1004        |
# |    iterations           | 39          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.007847408 |
# |    clip_fraction        | 0.0609      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2          |
# |    explained_variance   | -0.0168     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 869         |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0134     |
# |    value_loss           | 907         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 41.4        |
# |    ep_rew_mean          | 19.7        |
# | time/                   |             |
# |    fps                  | 1002        |
# |    iterations           | 40          |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.011695037 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2          |
# |    explained_variance   | 0.0918      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.4        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0241     |
# |    value_loss           | 367         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 41.5        |
# |    ep_rew_mean          | 20.6        |
# | time/                   |             |
# |    fps                  | 1001        |
# |    iterations           | 41          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.011028455 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.96       |
# |    explained_variance   | 0.151       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.9        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0215     |
# |    value_loss           | 454         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 43.2        |
# |    ep_rew_mean          | 12.9        |
# | time/                   |             |
# |    fps                  | 1000        |
# |    iterations           | 42          |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.012167323 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.99       |
# |    explained_variance   | 0.0502      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 31.3        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0193     |
# |    value_loss           | 510         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 40.8        |
# |    ep_rew_mean          | 21.7        |
# | time/                   |             |
# |    fps                  | 999         |
# |    iterations           | 43          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.011428561 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.97       |
# |    explained_variance   | 0.043       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 229         |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0167     |
# |    value_loss           | 605         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.5        |
# |    ep_rew_mean          | 29.4        |
# | time/                   |             |
# |    fps                  | 998         |
# |    iterations           | 44          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.009201758 |
# |    clip_fraction        | 0.0779      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.96       |
# |    explained_variance   | -0.0265     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.1        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0174     |
# |    value_loss           | 774         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 37.6       |
# |    ep_rew_mean          | 37.8       |
# | time/                   |            |
# |    fps                  | 996        |
# |    iterations           | 45         |
# |    time_elapsed         | 92         |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.01141409 |
# |    clip_fraction        | 0.132      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.96      |
# |    explained_variance   | 0.0682     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 248        |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.0215    |
# |    value_loss           | 543        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 37.2         |
# |    ep_rew_mean          | 41.3         |
# | time/                   |              |
# |    fps                  | 995          |
# |    iterations           | 46           |
# |    time_elapsed         | 94           |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0144224595 |
# |    clip_fraction        | 0.138        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 0.0594       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 24.6         |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.0189      |
# |    value_loss           | 774          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 37.8       |
# |    ep_rew_mean          | 38.7       |
# | time/                   |            |
# |    fps                  | 994        |
# |    iterations           | 47         |
# |    time_elapsed         | 96         |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.00986567 |
# |    clip_fraction        | 0.0994     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.92      |
# |    explained_variance   | 0.0736     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 515        |
# |    n_updates            | 460        |
# |    policy_gradient_loss | -0.0169    |
# |    value_loss           | 749        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 36.8        |
# |    ep_rew_mean          | 43.5        |
# | time/                   |             |
# |    fps                  | 993         |
# |    iterations           | 48          |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.008684747 |
# |    clip_fraction        | 0.0841      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.92       |
# |    explained_variance   | 0.0431      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.2        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0159     |
# |    value_loss           | 839         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 35.4        |
# |    ep_rew_mean          | 51.1        |
# | time/                   |             |
# |    fps                  | 992         |
# |    iterations           | 49          |
# |    time_elapsed         | 101         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.010089025 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.88       |
# |    explained_variance   | 0.0768      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 324         |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.02       |
# |    value_loss           | 735         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 37.4        |
# |    ep_rew_mean          | 43.2        |
# | time/                   |             |
# |    fps                  | 991         |
# |    iterations           | 50          |
# |    time_elapsed         | 103         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.008414669 |
# |    clip_fraction        | 0.0742      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.85       |
# |    explained_variance   | 0.105       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 844         |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0141     |
# |    value_loss           | 900         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 35.5       |
# |    ep_rew_mean          | 54.5       |
# | time/                   |            |
# |    fps                  | 990        |
# |    iterations           | 51         |
# |    time_elapsed         | 105        |
# |    total_timesteps      | 104448     |
# | train/                  |            |
# |    approx_kl            | 0.00975202 |
# |    clip_fraction        | 0.0969     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.85      |
# |    explained_variance   | 0.131      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 274        |
# |    n_updates            | 500        |
# |    policy_gradient_loss | -0.0172    |
# |    value_loss           | 771        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 35.8         |
# |    ep_rew_mean          | 55.2         |
# | time/                   |              |
# |    fps                  | 989          |
# |    iterations           | 52           |
# |    time_elapsed         | 107          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0100515755 |
# |    clip_fraction        | 0.113        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.83        |
# |    explained_variance   | 0.149        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 317          |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.0153      |
# |    value_loss           | 1.05e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 35.6        |
# |    ep_rew_mean          | 55.8        |
# | time/                   |             |
# |    fps                  | 989         |
# |    iterations           | 53          |
# |    time_elapsed         | 109         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.010709116 |
# |    clip_fraction        | 0.0886      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.75       |
# |    explained_variance   | 0.143       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 460         |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0146     |
# |    value_loss           | 971         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 32.4         |
# |    ep_rew_mean          | 74.1         |
# | time/                   |              |
# |    fps                  | 987          |
# |    iterations           | 54           |
# |    time_elapsed         | 112          |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0076172254 |
# |    clip_fraction        | 0.0563       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.72        |
# |    explained_variance   | 0.181        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 263          |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.0138      |
# |    value_loss           | 1.04e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 33.3        |
# |    ep_rew_mean          | 67.8        |
# | time/                   |             |
# |    fps                  | 980         |
# |    iterations           | 55          |
# |    time_elapsed         | 114         |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.009815948 |
# |    clip_fraction        | 0.075       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.73       |
# |    explained_variance   | 0.269       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 460         |
# |    n_updates            | 540         |
# ...
# |    learning_rate        | 0.0003      |
# |    loss                 | 273         |
# |    n_updates            | 4700        |
# |    policy_gradient_loss | -0.00453    |
# |    value_loss           | 341         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12.8        |
# |    ep_rew_mean          | 183         |
# | time/                   |             |
# |    fps                  | 970         |
# |    iterations           | 472         |
# |    time_elapsed         | 995         |
# |    total_timesteps      | 966656      |
# | train/                  |             |
# |    approx_kl            | 0.016351981 |
# |    clip_fraction        | 0.0973      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.473      |
# |    explained_variance   | 0.864       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 274         |
# |    n_updates            | 4710        |
# |    policy_gradient_loss | -0.00602    |
# |    value_loss           | 592         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 13.4        |
# |    ep_rew_mean          | 178         |
# | time/                   |             |
# |    fps                  | 971         |
# |    iterations           | 473         |
# |    time_elapsed         | 997         |
# |    total_timesteps      | 968704      |
# | train/                  |             |
# |    approx_kl            | 0.022514226 |
# |    clip_fraction        | 0.0922      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.463      |
# |    explained_variance   | 0.878       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 101         |
# |    n_updates            | 4720        |
# |    policy_gradient_loss | -0.00813    |
# |    value_loss           | 330         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 13.5        |
# |    ep_rew_mean          | 181         |
# | time/                   |             |
# |    fps                  | 971         |
# |    iterations           | 474         |
# |    time_elapsed         | 999         |
# |    total_timesteps      | 970752      |
# | train/                  |             |
# |    approx_kl            | 0.014185561 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.47       |
# |    explained_variance   | 0.861       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 46.8        |
# |    n_updates            | 4730        |
# |    policy_gradient_loss | -0.00811    |
# |    value_loss           | 448         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14.7        |
# |    ep_rew_mean          | 174         |
# | time/                   |             |
# |    fps                  | 971         |
# |    iterations           | 475         |
# |    time_elapsed         | 1001        |
# |    total_timesteps      | 972800      |
# | train/                  |             |
# |    approx_kl            | 0.028833222 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.495      |
# |    explained_variance   | 0.927       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.3        |
# |    n_updates            | 4740        |
# |    policy_gradient_loss | -0.00471    |
# |    value_loss           | 220         |
# -----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 16.2     |
# |    ep_rew_mean          | 165      |
# | time/                   |          |
# |    fps                  | 971      |
# |    iterations           | 476      |
# |    time_elapsed         | 1003     |
# |    total_timesteps      | 974848   |
# | train/                  |          |
# |    approx_kl            | 0.03691  |
# |    clip_fraction        | 0.125    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.448   |
# |    explained_variance   | 0.889    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 227      |
# |    n_updates            | 4750     |
# |    policy_gradient_loss | -0.00471 |
# |    value_loss           | 281      |
# --------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 18.1       |
# |    ep_rew_mean          | 160        |
# | time/                   |            |
# |    fps                  | 971        |
# |    iterations           | 477        |
# |    time_elapsed         | 1005       |
# |    total_timesteps      | 976896     |
# | train/                  |            |
# |    approx_kl            | 0.04718858 |
# |    clip_fraction        | 0.152      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.446     |
# |    explained_variance   | 0.869      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 31.2       |
# |    n_updates            | 4760       |
# |    policy_gradient_loss | -0.000575  |
# |    value_loss           | 350        |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 19.5      |
# |    ep_rew_mean          | 154       |
# | time/                   |           |
# |    fps                  | 971       |
# |    iterations           | 478       |
# |    time_elapsed         | 1007      |
# |    total_timesteps      | 978944    |
# | train/                  |           |
# |    approx_kl            | 0.0191166 |
# |    clip_fraction        | 0.115     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.489    |
# |    explained_variance   | 0.842     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 26.6      |
# |    n_updates            | 4770      |
# |    policy_gradient_loss | -0.00597  |
# |    value_loss           | 356       |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 13.4       |
# |    ep_rew_mean          | 180        |
# | time/                   |            |
# |    fps                  | 971        |
# |    iterations           | 479        |
# |    time_elapsed         | 1009       |
# |    total_timesteps      | 980992     |
# | train/                  |            |
# |    approx_kl            | 0.05524906 |
# |    clip_fraction        | 0.129      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.411     |
# |    explained_variance   | 0.854      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 18.8       |
# |    n_updates            | 4780       |
# |    policy_gradient_loss | -0.00574   |
# |    value_loss           | 299        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.9        |
# |    ep_rew_mean          | 193         |
# | time/                   |             |
# |    fps                  | 971         |
# |    iterations           | 480         |
# |    time_elapsed         | 1011        |
# |    total_timesteps      | 983040      |
# | train/                  |             |
# |    approx_kl            | 0.016788397 |
# |    clip_fraction        | 0.0873      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.337      |
# |    explained_variance   | 0.865       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.1        |
# |    n_updates            | 4790        |
# |    policy_gradient_loss | -0.00598    |
# |    value_loss           | 294         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11.6        |
# |    ep_rew_mean          | 188         |
# | time/                   |             |
# |    fps                  | 971         |
# |    iterations           | 481         |
# |    time_elapsed         | 1013        |
# |    total_timesteps      | 985088      |
# | train/                  |             |
# |    approx_kl            | 0.005380114 |
# |    clip_fraction        | 0.063       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.424      |
# |    explained_variance   | 0.833       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 282         |
# |    n_updates            | 4800        |
# |    policy_gradient_loss | -0.00871    |
# |    value_loss           | 795         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14.5        |
# |    ep_rew_mean          | 176         |
# | time/                   |             |
# |    fps                  | 971         |
# |    iterations           | 482         |
# |    time_elapsed         | 1015        |
# |    total_timesteps      | 987136      |
# | train/                  |             |
# |    approx_kl            | 0.034376033 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.427      |
# |    explained_variance   | 0.936       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32.7        |
# |    n_updates            | 4810        |
# |    policy_gradient_loss | -0.00634    |
# |    value_loss           | 191         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 13.1        |
# |    ep_rew_mean          | 182         |
# | time/                   |             |
# |    fps                  | 972         |
# |    iterations           | 483         |
# |    time_elapsed         | 1017        |
# |    total_timesteps      | 989184      |
# | train/                  |             |
# |    approx_kl            | 0.020825274 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.467      |
# |    explained_variance   | 0.902       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.6        |
# |    n_updates            | 4820        |
# |    policy_gradient_loss | -0.00381    |
# |    value_loss           | 284         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 16.7         |
# |    ep_rew_mean          | 165          |
# | time/                   |              |
# |    fps                  | 972          |
# |    iterations           | 484          |
# |    time_elapsed         | 1019         |
# |    total_timesteps      | 991232       |
# | train/                  |              |
# |    approx_kl            | 0.0059507336 |
# |    clip_fraction        | 0.0838       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.49        |
# |    explained_variance   | 0.835        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 263          |
# |    n_updates            | 4830         |
# |    policy_gradient_loss | -0.00624     |
# |    value_loss           | 549          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 14.8       |
# |    ep_rew_mean          | 175        |
# | time/                   |            |
# |    fps                  | 972        |
# |    iterations           | 485        |
# |    time_elapsed         | 1021       |
# |    total_timesteps      | 993280     |
# | train/                  |            |
# |    approx_kl            | 0.02605006 |
# |    clip_fraction        | 0.0998     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.49      |
# |    explained_variance   | 0.847      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 301        |
# |    n_updates            | 4840       |
# |    policy_gradient_loss | -0.00435   |
# |    value_loss           | 338        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12.5        |
# |    ep_rew_mean          | 184         |
# | time/                   |             |
# |    fps                  | 972         |
# |    iterations           | 486         |
# |    time_elapsed         | 1023        |
# |    total_timesteps      | 995328      |
# | train/                  |             |
# |    approx_kl            | 0.015346311 |
# |    clip_fraction        | 0.0996      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.453      |
# |    explained_variance   | 0.879       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.8        |
# |    n_updates            | 4850        |
# |    policy_gradient_loss | -0.0058     |
# |    value_loss           | 362         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 15.8        |
# |    ep_rew_mean          | 163         |
# | time/                   |             |
# |    fps                  | 972         |
# |    iterations           | 487         |
# |    time_elapsed         | 1025        |
# |    total_timesteps      | 997376      |
# | train/                  |             |
# |    approx_kl            | 0.030705187 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.443      |
# |    explained_variance   | 0.878       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.9        |
# |    n_updates            | 4860        |
# |    policy_gradient_loss | -0.0105     |
# |    value_loss           | 213         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 15.1        |
# |    ep_rew_mean          | 170         |
# | time/                   |             |
# |    fps                  | 972         |
# |    iterations           | 488         |
# |    time_elapsed         | 1027        |
# |    total_timesteps      | 999424      |
# | train/                  |             |
# |    approx_kl            | 0.018372782 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.471      |
# |    explained_variance   | 0.839       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 58.3        |
# |    n_updates            | 4870        |
# |    policy_gradient_loss | -0.0104     |
# |    value_loss           | 361         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 12.4       |
# |    ep_rew_mean          | 184        |
# | time/                   |            |
# |    fps                  | 972        |
# |    iterations           | 489        |
# |    time_elapsed         | 1030       |
# |    total_timesteps      | 1001472    |
# | train/                  |            |
# |    approx_kl            | 0.02420742 |
# |    clip_fraction        | 0.106      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.447     |
# |    explained_variance   | 0.857      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 22.3       |
# |    n_updates            | 4880       |
# |    policy_gradient_loss | -0.00632   |
# |    value_loss           | 432        |
# ----------------------------------------

# %%
cube_model_path = os.path.join('Training', 'Saved Models', 'Cube_Model')
model.save(cube_model_path)

# %%
#load
model = PPO.load(cube_model_path, env=env_cub)

# %%
evaluate_policy(model, env_cub, n_eval_episodes=10)
#score mean / standard deviation
# Out:
# (197.11333347260953, 58.1109579098235)
